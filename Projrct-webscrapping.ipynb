# %%
pip install scrapy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
import json

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('quoteresult.jl', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %%
import pandas as pd
quotes = pd.read_json('quoteresult.json')
quotes
# Out:
#                                                  text               author  \
# 0   “The world as we have created it is a process ...      Albert Einstein
# 1   “This life is what you make it. No matter what...       Marilyn Monroe
# 2   “It takes a great deal of bravery to stand up ...         J.K. Rowling
# 3   “It is our choices, Harry, that show what we t...         J.K. Rowling
# 4   “There are only two ways to live your life. On...      Albert Einstein
# 5   “The person, be it gentleman or lady, who has ...          Jane Austen
# 6   “Imperfection is beauty, madness is genius and...       Marilyn Monroe
# 7   “Try not to become a man of success. Rather be...      Albert Einstein
# 8   “It is better to be hated for what you are tha...           André Gide
# 9   “I have not failed. I've just found 10,000 way...     Thomas A. Edison
# 10  “A woman is like a tea bag; you never know how...    Eleanor Roosevelt
# ...

# %%
quotes = pd.read_json('quoteresult.jl', lines=True)
quotes
# Out:
#                                                  text               author  \
# 0   “The world as we have created it is a process ...      Albert Einstein
# 1   “This life is what you make it. No matter what...       Marilyn Monroe
# 2   “It takes a great deal of bravery to stand up ...         J.K. Rowling
# 3   “It is our choices, Harry, that show what we t...         J.K. Rowling
# 4   “There are only two ways to live your life. On...      Albert Einstein
# 5   “The person, be it gentleman or lady, who has ...          Jane Austen
# 6   “Imperfection is beauty, madness is genius and...       Marilyn Monroe
# 7   “Try not to become a man of success. Rather be...      Albert Einstein
# 8   “It is better to be hated for what you are tha...           André Gide
# 9   “I have not failed. I've just found 10,000 way...     Thomas A. Edison
# 10  “A woman is like a tea bag; you never know how...    Eleanor Roosevelt
# ...

# %%
quotes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    20 non-null     object
#  1   author  20 non-null     object
#  2   tags    20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
quotes['author'].value_counts()
# Out:
# Albert Einstein        4
# Marilyn Monroe         2
# J.K. Rowling           2
# Jane Austen            1
# André Gide             1
# Thomas A. Edison       1
# Eleanor Roosevelt      1
# Bob Marley             1
# Dr. Seuss              1
# Douglas Adams          1
# Elie Wiesel            1
# Friedrich Nietzsche    1
# Mark Twain             1
# Allen Saunders         1
# Steve Martin           1
# Name: author, dtype: int64

# %%
cols=quotes.drop("author",axis=1).columns
perc={}
for col in cols:
    perc[col]=round(quotes[col].value_counts(normalize=True)*100,2)
result=pd.read_json(perc).T
result.index=quests

result.style\
    .highlight_max(color = 'green',axis=1)\
    .highlight_min(color = 'yellow',axis=1)\
    .format('{:.0f}%')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [22], in <cell line: 5>()
#       3 for col in cols:
#       4     perc[col]=round(quotes[col].value_counts(normalize=True)*100,2)
# ----> 5 result=pd.read_json(perc).T
#       6 result.index=quests
#       8 result.style\
#       9     .highlight_max(color = 'green',axis=1)\
#      10     .highlight_min(color = 'yellow',axis=1)\
#      11     .format('{:.0f}%')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
# ...

# %%
quotes.describe()
# Out:
#                                                      text           author  \
# count                                                  20               20
# unique                                                 20               15
# top     “The world as we have created it is a process ...  Albert Einstein
# freq                                                    1                4
#
#                                             tags
# count                                         20
# unique                                        20
# top     [change, deep-thoughts, thinking, world]
# freq                                           1
